# %% [markdown]
# Import necessary packages.

# %%
# Dataframes and numerical
import pandas as pd
import numpy as np

# Geolocation
import geopandas as gpd
import matplotlib.pyplot as plt

# Apache parquet files (to save space)
import pyarrow as pa
import pyarrow.parquet as pq

# Increase pandas default display 
pd.options.display.max_rows = 250
pd.options.display.max_columns = 250

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reference shapefile and list of addresses to be tagged.

# %%
# From https://towardsdatascience.com/tagging-a-location-to-a-shapefile-area-using-geopandas-5d74336128bf

# Set the filepath and load in a shapefile
# Shape file found here:
# https://data.beta.nyc/dataset/pediacities-nyc-neighborhoods
fp = "CitiBike_data/archive/pediacitiesnycneighborhoods.json"
map_df = gpd.read_file(fp)

# Check the GeoDataframe
map_df.head()
# Out:
#       neighborhood boroughCode        borough  \
# 0         Allerton           2          Bronx
# 1  Alley Pond Park           4         Queens
# 2    Arden Heights           5  Staten Island
# 3        Arlington           5  Staten Island
# 4         Arrochar           5  Staten Island
#
#                                                  @id  \
# 0  http://nyc.pediacities.com/Resource/Neighborho...
# 1  http://nyc.pediacities.com/Resource/Neighborho...
# 2  http://nyc.pediacities.com/Resource/Neighborho...
# 3  http://nyc.pediacities.com/Resource/Neighborho...
# 4  http://nyc.pediacities.com/Resource/Neighborho...
#
#                                             geometry
# 0  POLYGON ((-73.84860 40.87167, -73.84582 40.870...
# 1  POLYGON ((-73.74333 40.73888, -73.74371 40.739...
# 2  POLYGON ((-74.16983 40.56108, -74.16982 40.561...
# 3  POLYGON ((-74.15975 40.64142, -74.15998 40.641...
# 4  POLYGON ((-74.06078 40.59319, -74.06079 40.593...

# %% [markdown]
# Load .parquet file into pandas dataframe.

# %%
# Load the CitiBike log file covering May 2021 through April 2022 and their Lat Longs
list_location = pq.read_table('CitiBike_data/202105-202204-citibike-tripdata.parquet').to_pandas()

# Check the Pandas Dataframe
list_location.head()
# Out:
#   member_casual rideable_type          started_at        start_station_name  \
# 1        Member  Classic Bike 2021-05-13 12:48:08        Broadway & W 25 St
# 2        Member  Classic Bike 2021-05-16 08:30:13             46 Ave & 5 St
# 3        Member  Classic Bike 2021-05-01 08:38:14             46 Ave & 5 St
# 4        Member  Classic Bike 2021-05-09 08:12:31             46 Ave & 5 St
# 5        Member  Classic Bike 2021-05-27 07:52:27  E 123 St & Lexington Ave
#
#    start_lat  start_lng start_boro         start_hood            ended_at  \
# 1  40.742868 -73.989186  Manhattan  Flatiron District 2021-05-13 13:07:37
# 2  40.747310 -73.954510     Queens      Hunters Point 2021-05-16 08:45:47
# 3  40.747310 -73.954510     Queens      Hunters Point 2021-05-01 08:54:27
# 4  40.747310 -73.954510     Queens      Hunters Point 2021-05-09 08:27:05
# 5  40.802926 -73.937900  Manhattan        East Harlem 2021-05-27 08:09:01
#
#          end_station_name    end_lat    end_lng   end_boro         end_hood  \
# 1       E 2 St & Avenue B  40.722175 -73.983688  Manhattan     East Village
# 2  34th Ave & Vernon Blvd  40.765354 -73.939863     Queens          Astoria
# 3  34th Ave & Vernon Blvd  40.765354 -73.939863     Queens          Astoria
# 4  34th Ave & Vernon Blvd  40.765354 -73.939863     Queens          Astoria
# 5         1 Ave & E 78 St  40.771404 -73.953516  Manhattan  Upper East Side
#
#    year  month  week_of_year  day_of_week  hour_of_day  duration_min  \
# 1  2021      5            19            3           12     19.483333
# 2  2021      5            19            6            8     15.566667
# 3  2021      5            17            5            8     16.216667
# 4  2021      5            18            6            8     14.566667
# 5  2021      5            21            3            7     16.566667
#
#    distance_mi  speed_mph
# 1     1.807254   5.565537
# 2     2.255646   8.694139
# 3     2.255646   8.345659
# 4     2.255646   9.290991
# 5     3.252584  11.779982

# %% [markdown]
# In order to conserve memory resources, a dataframe consisting of every conceivable station name and coordinates shall be created, tagged to boro and neighborhood, and finally assigned to the main dataframe.

# %% [markdown]
# However, the problem is that there is a lot of noise in the data regarding actual station locations. To illustrate, observe the number of unique station names for start and end stations as opposed to the number of unique latitudes and longitudes for each ride generated when duplicates are dropped. There are clearly more unique coordinates than there are stations to contain them.

# %%
len(list_location.start_station_name.unique().tolist())
# Out:
# 1588

# %%
list_location[['start_lat', 'start_lng']].drop_duplicates()
# Out:
#           start_lat  start_lng
# 1         40.742868 -73.989186
# 2         40.747310 -73.954510
# 5         40.802926 -73.937900
# 11        40.757973 -73.966033
# 18        40.710447 -73.965251
# ...             ...        ...
# 26498803  40.773913 -73.954395
# 26499040  40.752762 -73.992804
# 26504654  40.797523 -73.948942
# 26518872  40.754136 -73.996459
# 26532016  40.703662 -74.013181
#
# [1588 rows x 2 columns]

# %%
len(list_location.end_station_name.unique().tolist())
# Out:
# 1668

# %%
list_location[['end_lat', 'end_lng']].drop_duplicates()
# Out:
#             end_lat    end_lng
# 1         40.722175 -73.983688
# 2         40.765354 -73.939863
# 5         40.771404 -73.953516
# 6         40.735367 -73.987975
# 17        40.730562 -73.973985
# ...             ...        ...
# 26527966  40.797523 -73.948942
# 26532123  40.717597 -74.015882
# 26741144  40.754136 -73.996459
# 26819204  40.669767 -73.994744
# 28573549  40.739814 -74.036904
#
# [1668 rows x 2 columns]

# %% [markdown]
# The solution is to average all coordinates for each unique station name, which results in the number of unique coordinates matching their respective number of stations.

# %%
list_location[['start_station_name','start_lat', 'start_lng']].groupby(['start_station_name']).mean()
# Out:
#                               start_lat  start_lng
# start_station_name
# 1 Ave & E 110 St              40.792327 -73.938300
# 1 Ave & E 16 St               40.732219 -73.981655
# 1 Ave & E 18 St               40.733812 -73.980544
# 1 Ave & E 30 St               40.741444 -73.975361
# 1 Ave & E 39 St               40.747140 -73.971130
# ...                                 ...        ...
# Wyckoff Av & Stanhope St      40.703545 -73.917775
# Wyckoff Ave & Gates Ave       40.699871 -73.911718
# Wyckoff St & Nevins St        40.683426 -73.984275
# Wythe Ave & Metropolitan Ave  40.716887 -73.963198
# Yankee Ferry Terminal         40.687066 -74.016756
#
# [1588 rows x 2 columns]

# %%
list_location[['end_station_name','end_lat', 'end_lng']].groupby(['end_station_name']).mean()
# Out:
#                                 end_lat    end_lng
# end_station_name
# 1 Ave & E 110 St              40.792327 -73.938300
# 1 Ave & E 16 St               40.732219 -73.981655
# 1 Ave & E 18 St               40.733812 -73.980544
# 1 Ave & E 30 St               40.741444 -73.975361
# 1 Ave & E 39 St               40.747140 -73.971130
# ...                                 ...        ...
# Wyckoff Av & Stanhope St      40.703545 -73.917775
# Wyckoff Ave & Gates Ave       40.699871 -73.911718
# Wyckoff St & Nevins St        40.683426 -73.984275
# Wythe Ave & Metropolitan Ave  40.716887 -73.963198
# Yankee Ferry Terminal         40.687066 -74.016756
#
# [1668 rows x 2 columns]

# %% [markdown]
# Therefore, a dataframe of unique start station names and another one with unique end station names, both with averaged out coordinates, shall be generated and then merged to eliminate overlaps.

# %%
# Create a dataframe of unique start station names with coordinates
start_station_df = list_location[['start_station_name','start_lat', 'start_lng']] \
.groupby(['start_station_name']).mean()

# Create a dataframe of unique end station names with coordinates
end_station_df = list_location[['end_station_name','end_lat', 'end_lng']] \
.groupby(['end_station_name']).mean()

# Rename columns in both dataframes to assist merging
start_station_df.rename(columns = {'start_station_name': 'station_name',
                                  'start_lat': 'lat',
                                  'start_lng': 'lng'}, inplace = True)
end_station_df.rename(columns = {'end_station_name': 'station_name',
                                  'end_lat': 'lat',
                                  'end_lng': 'lng'}, inplace = True)

# Concatenate dataframes
stations_df = pd.concat([start_station_df, end_station_df]).drop_duplicates()

# Average out unique stations again to further streamline
stations_df = stations_df.groupby(stations_df.index).mean()

# Check dataframe finally
stations_df
# Out:
#                                     lat        lng
# 1 Ave & E 110 St              40.792327 -73.938300
# 1 Ave & E 16 St               40.732219 -73.981655
# 1 Ave & E 18 St               40.733812 -73.980544
# 1 Ave & E 30 St               40.741444 -73.975361
# 1 Ave & E 39 St               40.747140 -73.971130
# ...                                 ...        ...
# Wyckoff Av & Stanhope St      40.703545 -73.917775
# Wyckoff Ave & Gates Ave       40.699871 -73.911718
# Wyckoff St & Nevins St        40.683426 -73.984275
# Wythe Ave & Metropolitan Ave  40.716887 -73.963198
# Yankee Ferry Terminal         40.687066 -74.016756
#
# [1669 rows x 2 columns]

# %% [markdown]
# Extract coordinates from the streamlined Pandas dataframe

# %%
# Changing to a GeoDataFrame to create geometry series
stations_gp = gpd.GeoDataFrame(stations_df, geometry = gpd.points_from_xy(stations_df.lng, stations_df.lat))

# Checking GeoDataFrame
stations_gp.head()
# Out:
#                         lat        lng                    geometry
# 1 Ave & E 110 St  40.792327 -73.938300  POINT (-73.93830 40.79233)
# 1 Ave & E 16 St   40.732219 -73.981655  POINT (-73.98166 40.73222)
# 1 Ave & E 18 St   40.733812 -73.980544  POINT (-73.98054 40.73381)
# 1 Ave & E 30 St   40.741444 -73.975361  POINT (-73.97536 40.74144)
# 1 Ave & E 39 St   40.747140 -73.971130  POINT (-73.97113 40.74714)

# %% [markdown]
# Finally, create new columns to assign boro and neighborhood based on geometry point.

# %%
# Boro (or County)
stations_gp['boro'] = ''
for idx in range(map_df.shape[0]):
    # For every station , find if they reside within a boro
    pip = stations_gp.within(map_df.loc[idx, 'geometry'])
    if pip.sum() > 0: # Found where some of the station reside at map_df.loc[idx]
        stations_gp.loc[pip, 'boro']  = map_df.loc[idx, 'borough']

# Neighborhood
stations_gp['hood'] = ''
for idx in range(map_df.shape[0]):
    # For every station , find if they reside within a boro
    pip = stations_gp.within(map_df.loc[idx, 'geometry'])
    if pip.sum() > 0: # Found where some of the station reside at map_df.loc[idx]
        stations_gp.loc[pip, 'hood']  = map_df.loc[idx, 'neighborhood']

# %% [markdown]
# Check new GeoDataFrame of stations now.

# %%
stations_gp.head()
# Out:
#                         lat        lng                    geometry       boro  \
# 1 Ave & E 110 St  40.792327 -73.938300  POINT (-73.93830 40.79233)  Manhattan
# 1 Ave & E 16 St   40.732219 -73.981655  POINT (-73.98166 40.73222)  Manhattan
# 1 Ave & E 18 St   40.733812 -73.980544  POINT (-73.98054 40.73381)  Manhattan
# 1 Ave & E 30 St   40.741444 -73.975361  POINT (-73.97536 40.74144)  Manhattan
# 1 Ave & E 39 St   40.747140 -73.971130  POINT (-73.97113 40.74714)  Manhattan
#
#                              hood
# 1 Ave & E 110 St      East Harlem
# 1 Ave & E 16 St   Stuyvesant Town
# 1 Ave & E 18 St   Stuyvesant Town
# 1 Ave & E 30 St          Kips Bay
# 1 Ave & E 39 St       Murray Hill

# %%
stations_gp.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1669 entries, 1 Ave & E 110 St to Yankee Ferry Terminal
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lat       1669 non-null   float64
#  1   lng       1669 non-null   float64
#  2   geometry  1669 non-null   geometry
#  3   boro      1669 non-null   object
#  4   hood      1669 non-null   object
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 78.2+ KB

# %%
stations_gp.boro.value_counts()
# Out:
# Manhattan    673
# Brooklyn     485
# Bronx        268
# Queens       174
#               69
# Name: boro, dtype: int64

# %%
stations_gp.hood.value_counts()
# Out:
#                              69
# Harlem                       68
# Williamsburg                 66
# Bushwick                     62
# Midtown                      57
# Long Island City             55
# Sunset Park                  52
# Astoria                      48
# Upper West Side              45
# Upper East Side              45
# Washington Heights           45
# East Harlem                  43
# Ditmars Steinway             43
# East Village                 42
# Bedford-Stuyvesant           36
# Chelsea                      35
# Longwood                     35
# Lower East Side              31
# Hell's Kitchen               30
# Mott Haven                   28
# Greenpoint                   27
# Financial District           26
# West Village                 24
# Fordham                      24
# Inwood                       23
# Park Slope                   22
# Ridgewood                    22
# Fort Greene                  21
# Kingsbridge                  20
# Tribeca                      20
# Claremont Village            19
# Concourse                    18
# Red Hook                     17
# Crown Heights                17
# SoHo                         16
# Gowanus                      16
# Morris Heights               15
# Carroll Gardens              13
# Greenwich Village            13
# Concourse Village            13
# Prospect Park                13
# Brooklyn Heights             12
# Windsor Terrace              12
# University Heights           12
# East Morrisania              12
# Clinton Hill                 11
# Morningside Heights          11
# Central Park                 11
# Kips Bay                     11
# Downtown Brooklyn            10
# Morrisania                   10
# Theater District             10
# Highbridge                   10
# Chinatown                    10
# Mount Hope                   10
# Kensington                    9
# Boerum Hill                   9
# Melrose                       9
# Port Morris                   9
# Norwood                       9
# Murray Hill                   9
# Prospect Heights              8
# Gramercy                      8
# Stuyvesant Town               8
# Vinegar Hill                  7
# Cobble Hill                   6
# Hunts Point                   6
# Navy Yard                     6
# Battery Park City             6
# Bay Ridge                     6
# Woodside                      6
# DUMBO                         6
# Mount Eden                    5
# South Slope                   5
# Columbia St                   5
# Civic Center                  4
# Randall's Island              4
# Flatiron District             4
# Green-Wood Cemetery           4
# Flatbush                      3
# Two Bridges                   3
# Crotona Park                  3
# Nolita                        3
# Roosevelt Island              3
# Governors Island              3
# NoHo                          2
# Prospect-Lefferts Gardens     2
# Cypress Hills                 2
# Tremont                       1
# Name: hood, dtype: int64

# %% [markdown]
# Investigate which listings are not in any of the distict boroughs of New York City.

# %%
stations_gp.loc[stations_gp.boro == '']
# Out:
#                                                     lat        lng  \
# 11 St & Washington St                         40.749985 -74.027150
# 12 St & Sinatra Dr N                          40.750604 -74.024020
# 14 St Ferry - 14 St & Shipyard Ln             40.752961 -74.024353
# 2 St HBLR - 2 St & Marshall St                40.740802 -74.042435
# 5 Corners Library                             40.734961 -74.059503
# 6 St & Grand St                               40.744398 -74.034501
# 7 St & Monroe St                              40.746413 -74.037977
# 8 St & Washington St                          40.745984 -74.028199
# Adams St & 11 St                              40.750916 -74.033541
# Adams St & 2 St                               40.739814 -74.036904
# Astor Place                                   40.719282 -74.071262
# Baldwin at Montgomery                         40.723659 -74.064194
# Bergen Ave                                    40.722104 -74.071455
# Bloomfield St & 15 St                         40.754530 -74.026580
# Brunswick & 6th                               40.726012 -74.050389
# Brunswick St                                  40.724176 -74.050656
# Christ Hospital                               40.734786 -74.050444
# Church Sq Park - 5 St & Park Ave              40.742659 -74.032233
# City Hall                                     40.717732 -74.043845
# City Hall - Washington St & 1 St              40.737360 -74.030970
# Clinton St & 7 St                             40.745420 -74.033320
# Clinton St & Newark St                        40.737430 -74.035710
# Columbus Dr at Exchange Pl                    40.716870 -74.032810
# Columbus Drive                                40.718355 -74.038914
# Columbus Park - Clinton St & 9 St             40.748161 -74.032453
# Dey St                                        40.737711 -74.066921
# Dixon Mills                                   40.721630 -74.049968
# Essex Light Rail                              40.712774 -74.036486
# Grand St                                      40.715178 -74.037683
# Grand St & 14 St                              40.754090 -74.031600
# Grove St PATH                                 40.719586 -74.043117
# Hamilton Park                                 40.727596 -74.044247
# Harborside                                    40.719252 -74.034234
# Heights Elevator                              40.748716 -74.040443
# Hilltop                                       40.731169 -74.057574
# Hoboken Ave at Monmouth St                    40.735208 -74.046964
# Hoboken Terminal - Hudson St & Hudson Pl      40.735938 -74.030305
# Hoboken Terminal - River St & Hudson Pl       40.736068 -74.029127
# Hudson St & 4 St                              40.740973 -74.028603
# JC Medical Center                             40.716540 -74.049638
# JCBS Depot                                    40.709651 -74.068601
# Jackson Square                                40.711130 -74.078900
# Jersey & 3rd                                  40.723332 -74.045953
# Jersey & 6th St                               40.725289 -74.045572
# Journal Square                                40.733670 -74.062500
# Liberty Light Rail                            40.711242 -74.055701
# Madison St & 1 St                             40.738790 -74.039300
# Mama Johnson Field - 4 St & Jackson St        40.743140 -74.040041
# Manila & 1st                                  40.721651 -74.042884
# Marin Light Rail                              40.714584 -74.042817
# McGinley Square                               40.725340 -74.067622
# Monmouth and 6th                              40.725685 -74.048790
# Montgomery St                                 40.719420 -74.050990
# Morris Canal                                  40.712419 -74.038526
# Newark Ave                                    40.721525 -74.046305
# Newport PATH                                  40.727224 -74.033759
# Newport Pkwy                                  40.728745 -74.032108
# Paulus Hook                                   40.714145 -74.033552
# Pershing Field                                40.742677 -74.051789
# Riverview Park                                40.744319 -74.043991
# Sip Ave                                       40.730897 -74.063913
# South Waterfront Walkway - Sinatra Dr & 1 St  40.736982 -74.027781
# Southwest Park - Jackson St & Observer Hwy    40.737551 -74.041664
# Stevens - River Ter & 6 St                    40.743133 -74.026989
# Union St                                      40.718211 -74.083639
# Van Vorst Park                                40.718489 -74.047727
# Warren St                                     40.721124 -74.038051
# Washington St                                 40.724294 -74.035483
# Willow Ave & 12 St                            40.751867 -74.030377
#
#                                                                 geometry boro  \
# 11 St & Washington St                         POINT (-74.02715 40.74998)
# 12 St & Sinatra Dr N                          POINT (-74.02402 40.75060)
# 14 St Ferry - 14 St & Shipyard Ln             POINT (-74.02435 40.75296)
# 2 St HBLR - 2 St & Marshall St                POINT (-74.04243 40.74080)
# 5 Corners Library                             POINT (-74.05950 40.73496)
# 6 St & Grand St                               POINT (-74.03450 40.74440)
# 7 St & Monroe St                              POINT (-74.03798 40.74641)
# 8 St & Washington St                          POINT (-74.02820 40.74598)
# Adams St & 11 St                              POINT (-74.03354 40.75092)
# Adams St & 2 St                               POINT (-74.03690 40.73981)
# Astor Place                                   POINT (-74.07126 40.71928)
# Baldwin at Montgomery                         POINT (-74.06419 40.72366)
# Bergen Ave                                    POINT (-74.07146 40.72210)
# Bloomfield St & 15 St                         POINT (-74.02658 40.75453)
# Brunswick & 6th                               POINT (-74.05039 40.72601)
# Brunswick St                                  POINT (-74.05066 40.72418)
# Christ Hospital                               POINT (-74.05044 40.73479)
# Church Sq Park - 5 St & Park Ave              POINT (-74.03223 40.74266)
# City Hall                                     POINT (-74.04385 40.71773)
# City Hall - Washington St & 1 St              POINT (-74.03097 40.73736)
# Clinton St & 7 St                             POINT (-74.03332 40.74542)
# Clinton St & Newark St                        POINT (-74.03571 40.73743)
# Columbus Dr at Exchange Pl                    POINT (-74.03281 40.71687)
# Columbus Drive                                POINT (-74.03891 40.71836)
# Columbus Park - Clinton St & 9 St             POINT (-74.03245 40.74816)
# Dey St                                        POINT (-74.06692 40.73771)
# Dixon Mills                                   POINT (-74.04997 40.72163)
# Essex Light Rail                              POINT (-74.03649 40.71277)
# Grand St                                      POINT (-74.03768 40.71518)
# Grand St & 14 St                              POINT (-74.03160 40.75409)
# Grove St PATH                                 POINT (-74.04312 40.71959)
# Hamilton Park                                 POINT (-74.04425 40.72760)
# Harborside                                    POINT (-74.03423 40.71925)
# Heights Elevator                              POINT (-74.04044 40.74872)
# Hilltop                                       POINT (-74.05757 40.73117)
# Hoboken Ave at Monmouth St                    POINT (-74.04696 40.73521)
# Hoboken Terminal - Hudson St & Hudson Pl      POINT (-74.03030 40.73594)
# Hoboken Terminal - River St & Hudson Pl       POINT (-74.02913 40.73607)
# Hudson St & 4 St                              POINT (-74.02860 40.74097)
# JC Medical Center                             POINT (-74.04964 40.71654)
# JCBS Depot                                    POINT (-74.06860 40.70965)
# Jackson Square                                POINT (-74.07890 40.71113)
# Jersey & 3rd                                  POINT (-74.04595 40.72333)
# Jersey & 6th St                               POINT (-74.04557 40.72529)
# Journal Square                                POINT (-74.06250 40.73367)
# Liberty Light Rail                            POINT (-74.05570 40.71124)
# Madison St & 1 St                             POINT (-74.03930 40.73879)
# Mama Johnson Field - 4 St & Jackson St        POINT (-74.04004 40.74314)
# Manila & 1st                                  POINT (-74.04288 40.72165)
# Marin Light Rail                              POINT (-74.04282 40.71458)
# McGinley Square                               POINT (-74.06762 40.72534)
# Monmouth and 6th                              POINT (-74.04879 40.72569)
# Montgomery St                                 POINT (-74.05099 40.71942)
# Morris Canal                                  POINT (-74.03853 40.71242)
# Newark Ave                                    POINT (-74.04630 40.72153)
# Newport PATH                                  POINT (-74.03376 40.72722)
# Newport Pkwy                                  POINT (-74.03211 40.72874)
# Paulus Hook                                   POINT (-74.03355 40.71415)
# Pershing Field                                POINT (-74.05179 40.74268)
# Riverview Park                                POINT (-74.04399 40.74432)
# Sip Ave                                       POINT (-74.06391 40.73090)
# South Waterfront Walkway - Sinatra Dr & 1 St  POINT (-74.02778 40.73698)
# Southwest Park - Jackson St & Observer Hwy    POINT (-74.04166 40.73755)
# Stevens - River Ter & 6 St                    POINT (-74.02699 40.74313)
# Union St                                      POINT (-74.08364 40.71821)
# Van Vorst Park                                POINT (-74.04773 40.71849)
# Warren St                                     POINT (-74.03805 40.72112)
# Washington St                                 POINT (-74.03548 40.72429)
# Willow Ave & 12 St                            POINT (-74.03038 40.75187)
#
#                                              hood
# 11 St & Washington St
# 12 St & Sinatra Dr N
# 14 St Ferry - 14 St & Shipyard Ln
# 2 St HBLR - 2 St & Marshall St
# 5 Corners Library
# 6 St & Grand St
# 7 St & Monroe St
# 8 St & Washington St
# Adams St & 11 St
# Adams St & 2 St
# Astor Place
# Baldwin at Montgomery
# Bergen Ave
# Bloomfield St & 15 St
# Brunswick & 6th
# Brunswick St
# Christ Hospital
# Church Sq Park - 5 St & Park Ave
# City Hall
# City Hall - Washington St & 1 St
# Clinton St & 7 St
# Clinton St & Newark St
# Columbus Dr at Exchange Pl
# Columbus Drive
# Columbus Park - Clinton St & 9 St
# Dey St
# Dixon Mills
# Essex Light Rail
# Grand St
# Grand St & 14 St
# Grove St PATH
# Hamilton Park
# Harborside
# Heights Elevator
# Hilltop
# Hoboken Ave at Monmouth St
# Hoboken Terminal - Hudson St & Hudson Pl
# Hoboken Terminal - River St & Hudson Pl
# Hudson St & 4 St
# JC Medical Center
# JCBS Depot
# Jackson Square
# Jersey & 3rd
# Jersey & 6th St
# Journal Square
# Liberty Light Rail
# Madison St & 1 St
# Mama Johnson Field - 4 St & Jackson St
# Manila & 1st
# Marin Light Rail
# McGinley Square
# Monmouth and 6th
# Montgomery St
# Morris Canal
# Newark Ave
# Newport PATH
# Newport Pkwy
# Paulus Hook
# Pershing Field
# Riverview Park
# Sip Ave
# South Waterfront Walkway - Sinatra Dr & 1 St
# Southwest Park - Jackson St & Observer Hwy
# Stevens - River Ter & 6 St
# Union St
# Van Vorst Park
# Warren St
# Washington St
# Willow Ave & 12 St

# %% [markdown]
# It appears that those stations are in New Jersey for the few crazy riders that decide to cross the Hudson River, either by ferry with the bike in tow, or through crossing a bridge or tunnel illegally. Fortunately, they are all in Hudson County, so then a shape file shall be used in order to fill in the gaps.
#
# Found here: https://catalog.data.gov/dataset/tiger-line-shapefile-2016-state-new-jersey-current-place-state-based

# %%
# Set the filepath and load in a shapefile
fp2 = "CitiBike_data/archive/tl_2016_34_place/tl_2016_34_place.shp"
map_df2 = gpd.read_file(fp2)

# Check the GeoDataframe
map_df2.head()
# Out:
#   STATEFP PLACEFP   PLACENS    GEOID            NAME                NAMELSAD  \
# 0      34   07600  00885169  3407600       Bridgeton          Bridgeton city
# 1      34   67020  00885393  3467020          Shiloh          Shiloh borough
# 2      34   07810  00885171  3407810      Brigantine         Brigantine city
# 3      34   23940  00885222  3423940          Folsom          Folsom borough
# 4      34   24990  00885225  3424990  Franklin Lakes  Franklin Lakes borough
#
#   LSAD CLASSFP PCICBSA PCINECTA  MTFCC FUNCSTAT     ALAND    AWATER  \
# 0   25      C5       Y        N  G4110        A  16131425    690143
# 1   21      C5       N        N  G4110        A   3116143      1564
# 2   25      C5       N        N  G4110        A  16931323  11204171
# 3   21      C5       N        N  G4110        A  21403550    635219
# 4   21      C5       N        N  G4110        A  24383136   1214222
#
#       INTPTLAT      INTPTLON  \
# 0  +39.4291920  -075.2285950
# 1  +39.4624183  -075.2924402
# 2  +39.4138574  -074.3779024
# 3  +39.5967446  -074.8431626
# 4  +41.0075259  -074.2056527
#
#                                             geometry
# 0  POLYGON ((-75.25302 39.44406, -75.24995 39.445...
# 1  POLYGON ((-75.31133 39.46395, -75.31132 39.464...
# 2  POLYGON ((-74.42105 39.38576, -74.42069 39.385...
# 3  POLYGON ((-74.88443 39.60217, -74.88338 39.603...
# 4  POLYGON ((-74.24851 40.99220, -74.24847 40.992...

# %%
map_df2.geometry
# Out:
# 0      POLYGON ((-75.25302 39.44406, -75.24995 39.445...
# 1      POLYGON ((-75.31133 39.46395, -75.31132 39.464...
# 2      POLYGON ((-74.42105 39.38576, -74.42069 39.385...
# 3      POLYGON ((-74.88443 39.60217, -74.88338 39.603...
# 4      POLYGON ((-74.24851 40.99220, -74.24847 40.992...
#                              ...
# 540    POLYGON ((-75.01234 39.67058, -75.00946 39.673...
# 541    POLYGON ((-74.30847 40.54117, -74.30840 40.541...
# 542    POLYGON ((-74.70470 40.18483, -74.70469 40.185...
# 543    POLYGON ((-74.35499 40.30243, -74.35464 40.302...
# 544    POLYGON ((-74.58222 40.53504, -74.58144 40.535...
# Name: geometry, Length: 545, dtype: geometry

# %% [markdown]
# Run this again for the New Jersey cities.

# %%
# Neighborhood
for idx in range(map_df2.shape[0]):
    # For every station , find if they reside within a boro
    pip = stations_gp.within(map_df2.loc[idx, 'geometry'])
    if pip.sum() > 0: # Found where some of the station reside at map_df.loc[idx]
        stations_gp.loc[pip, 'hood']  = map_df2.loc[idx, 'NAME']

# %%
stations_gp.loc[stations_gp.boro == '']['hood'].value_counts()
# Out:
# Jersey City    44
# Hoboken        25
# Name: hood, dtype: int64

# %%
stations_gp['boro'].loc[stations_gp.boro == ''] = 'New Jersey'

# %%
stations_gp.boro.value_counts()
# Out:
# Manhattan     673
# Brooklyn      485
# Bronx         268
# Queens        174
# New Jersey     69
# Name: boro, dtype: int64

# %%
stations_gp.isna().sum()
# Out:
# lat         0
# lng         0
# geometry    0
# boro        0
# hood        0
# dtype: int64

# %%
stations_gp.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1669 entries, 1 Ave & E 110 St to Yankee Ferry Terminal
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lat       1669 non-null   float64
#  1   lng       1669 non-null   float64
#  2   geometry  1669 non-null   geometry
#  3   boro      1669 non-null   object
#  4   hood      1669 non-null   object
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 78.2+ KB

# %%
stations_gp.head()
# Out:
#                         lat        lng                    geometry       boro  \
# 1 Ave & E 110 St  40.792327 -73.938300  POINT (-73.93830 40.79233)  Manhattan
# 1 Ave & E 16 St   40.732219 -73.981655  POINT (-73.98166 40.73222)  Manhattan
# 1 Ave & E 18 St   40.733812 -73.980544  POINT (-73.98054 40.73381)  Manhattan
# 1 Ave & E 30 St   40.741444 -73.975361  POINT (-73.97536 40.74144)  Manhattan
# 1 Ave & E 39 St   40.747140 -73.971130  POINT (-73.97113 40.74714)  Manhattan
#
#                              hood
# 1 Ave & E 110 St      East Harlem
# 1 Ave & E 16 St   Stuyvesant Town
# 1 Ave & E 18 St   Stuyvesant Town
# 1 Ave & E 30 St          Kips Bay
# 1 Ave & E 39 St       Murray Hill

# %% [markdown]
# Since all stations have had their respective boroughs and neighborhoods accounted for, it is time to save this GeoDataFrame as a simple Pandas dataframe with these values saved for easy reference.

# %%
CB_stations_locations = pd.DataFrame(stations_gp.drop(columns='geometry'))

# %%
type(CB_stations_locations)
# Out:
# pandas.core.frame.DataFrame

# %%
CB_stations_locations.head()
# Out:
#                         lat        lng       boro             hood
# 1 Ave & E 110 St  40.792327 -73.938300  Manhattan      East Harlem
# 1 Ave & E 16 St   40.732219 -73.981655  Manhattan  Stuyvesant Town
# 1 Ave & E 18 St   40.733812 -73.980544  Manhattan  Stuyvesant Town
# 1 Ave & E 30 St   40.741444 -73.975361  Manhattan         Kips Bay
# 1 Ave & E 39 St   40.747140 -73.971130  Manhattan      Murray Hill

# %%
CB_stations_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1669 entries, 1 Ave & E 110 St to Yankee Ferry Terminal
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     1669 non-null   float64
#  1   lng     1669 non-null   float64
#  2   boro    1669 non-null   object
#  3   hood    1669 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 65.2+ KB

# %% [markdown]
# Finally, save to .parquet

# %%
CB_Data_arrow = pa.Table.from_pandas(CB_stations_locations)
pq.write_table(CB_Data_arrow, 'CitiBike_data/202206-citibike-stations.parquet')
